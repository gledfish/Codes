# %%
import numpy 
speed = [99, 86, 87, 88, 111, 86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print(x)
# Out:
# 89.76923076923077

# %%
speed = [86,87,88,86,87,85,86]

x = numpy.mean(speed)
dx = numpy.std(speed)
print(x)
print(dx)
# Out:
# 86.42857142857143
# 0.9035079029052513

# %%
x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [0.28366358 3.33342641 1.04132519 4.45524691 4.14981501 4.75883813
#  0.38135652 3.69922168 2.90652993 4.24928269 3.39011754 3.70406646
#  0.61025262 2.84568531 1.63404818 2.20430928 4.70988752 3.30347007
#  1.87031319 4.3074844  3.25781723 0.71256979 4.24012362 0.02496479
#  2.62390221 3.53581468 3.80829882 1.54009436 3.36065252 2.08554256
#  2.06627626 4.34407389 3.45269693 4.88490317 2.95850311 2.45887915
#  1.99862323 2.22890549 2.10399999 2.60525865 1.48869995 2.66384712
#  4.0476816  1.23828048 4.90652464 0.67832792 0.96339164 0.92384357
#  2.41541759 3.3015332  1.45157656 4.63006324 4.503346   3.06403084
#  0.68910665 1.25758434 2.52485978 0.69487348 2.43712916 4.53679303
#  1.4870862  0.9446465  4.70952136 1.75038853 0.62821007 1.62306019
#  4.94796391 1.28348481 4.81009445 0.36001137 0.0574688  3.45290739
#  1.64623705 0.72792259 0.74376585 2.27692811 4.96297778 4.32784906
#  0.1426693  2.08710074 3.58577686 0.15449337 2.34521633 2.07025652
#  0.02070791 2.91900348 3.78151805 1.41594927 4.8439465  0.42942818
#  3.776172   4.93645165 0.52776637 2.4703076  4.13719693 1.22861962
#  0.29602916 2.11594853 1.61658157 4.56352387 2.58093614 3.68443867
#  0.00644131 3.52924771 4.5803945  0.00942814 4.22465305 0.92916788
#  1.08378901 0.00960628 3.39652276 1.35816534 2.13224129 0.63858331
#  3.87786789 1.87699162 4.73677848 1.87620952 2.19977858 2.50222548
#  4.7753679  1.95974643 3.6463234  0.9340668  1.05801085 0.00758901
#  4.80909881 0.99453006 3.998573   4.19835805 0.65074971 2.77813856
#  1.8605843  2.87066133 3.38254936 1.11482196 1.46483069 1.73742666
#  2.47641127 4.00328043 3.77938947 4.68127015 1.52065414 2.27091668
#  0.65850383 2.49227877 2.41703618 3.80013819 0.58895818 3.62608153
#  4.33256498 1.23960046 4.63856191 4.27965413 1.88375884 1.07233656
#  1.36810494 0.19158155 2.49890956 2.22572417 3.95438783 4.15426109
#  0.54980058 3.35653423 2.36400377 3.11220408 4.52891646 2.71746513
#  4.18607166 3.23276612 0.07528363 3.51375817 0.94311795 3.9584396
#  0.51682281 2.15446368 1.8885787  1.02470964 3.74525286 4.70747073
#  4.75100273 3.22034955 3.84648705 1.11447412 2.33729631 1.47623707
#  0.72076387 4.87358447 3.57573303 3.37342027 1.17617658 4.11154095
#  3.65261593 0.33442795 2.63144218 0.7144166  1.56639707 3.35053637
#  2.58111445 3.91686581 2.24130983 2.53483591 2.96306796 2.71197007
#  1.17894958 4.35735999 1.53755718 3.29488521 4.30903528 3.76691469
#  3.84504171 0.04267881 4.0427384  3.84136961 1.27069641 0.28272357
#  1.86006494 4.73004539 4.93088091 0.39276443 1.19017225 1.79454376
#  2.47509607 4.96411445 3.17639107 3.79118503 0.29683371 1.19992949
#  2.05579058 4.13125563 1.70106933 0.80013675 2.27229278 4.24114784
#  4.51959332 0.50838958 4.95466961 0.42914379 4.33944915 0.05892644
#  1.02401782 1.26658216 1.50149696 4.50486395 3.35433769 1.06651549
#  2.72009955 3.01411245 2.43023535 0.4098254 ]

# %%
import matplotlib.pyplot as plt

plt.hist(x, 5)
plt.show()

# %%
x = numpy.random.uniform(0.0, 5.0, 10000)

plt.hist(x, 100)
plt.show()

# %%
x = numpy.random.normal(5.0, 1.0, 1000000000)

plt.hist(x, 100)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y) # 斜率，截距，相关系数，p, 标准差
def myfunc(x):
    return slope * x + intercept
mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %%
import numpy as plt
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy. polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
print(r2_score(y, mymodel(x)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 import numpy as plt
#       2 import matplotlib.pyplot as plt
# ----> 3 from sklearn.metrics import r2_score
#       4 x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
#       5 y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd
from sklearn import linear_model

df = pd.read_csv('data.csv')

X = df['Weight', 'Volume']
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

predited_CO2 = regr.predict([[2300, 1300]])
print(predictedCO2)

# %%
from sklearn import tree
import matplotlib.pyplot as plt
import pandas
from sklearn import DecisionTreeClassifier

# 读取数据
df = pd.read_csv('data.csv')

# 处理非数字值
d = {'UK':0, 'USA':1, 'N':2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES':1, 'NO':0}
df['GO'] = df['GO'].map(d)

# 特征值
features = ['Age', 'Experience', 'Rank', 'Nationality']
X = df[features]
y = df['Go']

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
